# %% [markdown]
# # Cohort Discovery NLP — `/llm/*` endpoint sandbox
#
# Exercises the experimental LLM-backed query parsing endpoints.
#
# **Before running:** start Ollama (`ollama serve`), pull a model (`ollama pull qwen3:8b`), and start the NLP service:
#
# ```bash
# uvicorn app:app --host 0.0.0.0 --port 5001
# ```
#
# Wait for `CORE READY` in the log before trusting concept matches — before that the resolver runs in reduced mode (LIKE-based SQL, no synonym or acronym enrichment).

# %% [markdown]
# ## Test queries
#
# `# NOT IMPLEMENTED` marks things the platform cannot support regardless of parsing — BUNNY has no visit table, no "followed by", no measurement-value filters. The other notes flag genuine parsing ambiguities.

# %%
SIMPLE_QUERIES = [
    "Women who were under 60 when they suffered a hip fracture",  # age constraint applies to the hip fracture, not the person
    "Adults aged 18-30 with a diagnosis of asthma",  # ambiguous: age of person vs age at diagnosis
    "People aged 65+ with diagnosed hypertension",  # ambiguous: age of person vs age at diagnosis
    "Adults with type 2 diabetes diagnosed in the last 2 years",  # needs timeConstraint [now-2y, now]
    "Children under 5 with at least 3 GP visits for ear infections in 12 months",  # NOT IMPLEMENTED: visits not supported by BUNNY
    "People with chronic kidney disease stage 3-5",
    "People with CKD",  # acronym
    "People with Chronic Kidney Disease",
    "People with Renal Failure",
    "Adults with BMI over 30",  # ambiguous 'adults'; numeric threshold
    "Obese Adults",
    "Adults with Obesity",
    "Adults with COPD",  # ambiguous 'adults'; acronym
    "Children with COPD",
    "People with epilepsy currently under specialist neurology care",  # NOT IMPLEMENTED: neurology care is a visit
    "Women aged 18-45 with endometriosis",  # ambiguous age constraint
    "Men aged 50+ with benign prostatic hyperplasia",  # ambiguous age constraint
    "People aged 40+ with atrial fibrillation",  # ambiguous age constraint
    "Adults with heart failure",  # ambiguous 'adults'
    "People with stroke recorded in the last 5 years",
    "Adults with diagnosed depression",  # ambiguous 'adults'
    "Adults with severe mental illness",  # ambiguous 'adults'
    "People with schizophrenia",
    "Adults with bipolar disorder",
    "People with dementia diagnosis",
    "Adults with rheumatoid arthritis",  # ambiguous 'adults'
    "People with inflammatory bowel disease",
    "People with Crohn's disease",
    "People with ulcerative colitis",
    "Adults with a recorded allergy to penicillin",  # ambiguous 'adults'
]

# %%
ADVANCED_QUERIES = [
    "People with cancer over the age of 50 who have been treated for hip fractures",
    "Men over 60 with cancer in NHS Scotland Regions",  # NOT IMPLEMENTED: location
    "Men over 60 with cancer in the South West",  # NOT IMPLEMENTED: location
    "Individuals who have antibodies to SARs-CoV-2 measured after receiving two doses of any COVID-19 vaccine",
    "Black men over the age of 60 who have had heart attacks while being on blood thinners",  # race in demographics
    "Adults with type 2 diabetes and at least one HbA1c result above 75 mmol/mol in the last year",  # NOT IMPLEMENTED: filter on measurement value
    "People with chronic kidney disease and an eGFR below 45 on two occasions at least 90 days apart",  # NOT IMPLEMENTED: filter on measurement value
    "Adults with hypertension who are not currently prescribed any antihypertensive medication",  # negative queries are a poor fit for cohort discovery
    "People with asthma who have had 2+ oral steroid courses in the last 12 months",  # NOT IMPLEMENTED: multiple occurrences
    "People with asthma who have had oral steroid courses in the last 12 months",  # the supported reduction of the query above
    "Adults with COPD who started home oxygen therapy in the last 2 years",
    "People with atrial fibrillation who have had an ischaemic stroke despite being prescribed anticoagulation",
    "Women with polycystic ovary syndrome who later developed type 2 diabetes",  # followed_by
    "Pregnant women with gestational diabetes who delivered preterm",
    "Pregnant women with gestational diabetes who delivered before 37 weeks",
    "Children diagnosed with autism who also have epilepsy",  # ambiguous 'children'
    "People with depression who started an SSRI and then switched antidepressant within 6 months",  # SSRI is a drug-class acronym
    "Adults prescribed long-term opioids (90+ consecutive days) for non-cancer pain",  # NOT IMPLEMENTED: consecutive days; user-defined 'long-term'
    "People with osteoarthritis who received a knee replacement and had a postoperative infection within 90 days",
    "Adults with a new diagnosis of heart failure who had no recorded hypertension beforehand",  # NOT IMPLEMENTED: BUNNY cannot filter 'followed by'
    "People with colorectal cancer who received chemotherapy and later developed neutropenia requiring hospital admission",  # NOT IMPLEMENTED: 'followed by'
    "Adults with breast cancer who later developed cardiomyopathy after anthracycline treatment",  # NOT IMPLEMENTED: 'followed by'
    "People with long COVID codes and persistent breathlessness recorded 12+ weeks after acute infection",  # NOT IMPLEMENTED: 'followed by'
    "Adults admitted with pneumonia who were not vaccinated against influenza that season",  # NOT IMPLEMENTED: 'followed by'
    "People with type 2 diabetes and COPD, and all-cause mortality within 5 years of COPD diagnosis",  # NOT IMPLEMENTED: 'followed by'
    "Adults with severe obesity who underwent bariatric surgery and had type 2 diabetes remission within 12 months",
    "People with migraine who started a CGRP inhibitor and had reduced emergency attendances afterward",  # NOT IMPLEMENTED: visits
    "Adults with psoriasis on systemic therapy who developed serious infection requiring hospitalisation",  # NOT IMPLEMENTED: visits
]

# %%
ALL_QUERIES = SIMPLE_QUERIES + ADVANCED_QUERIES
len(SIMPLE_QUERIES), len(ADVANCED_QUERIES), len(ALL_QUERIES)

# %% [markdown]
# ## Setup

# %%
import json
import time
from collections import Counter

import httpx
import pandas as pd

BASE = "http://localhost:5001"


def parse(query, fill_concepts=True, model=None, **params):
    """POST /llm/parse. Raises with the server's detail message on error."""
    body = {"query": query, "fill_concepts": fill_concepts}
    if model:
        body["model"] = model
    r = httpx.post(f"{BASE}/llm/parse", json=body, params=params, timeout=300)
    if r.status_code != 200:
        raise RuntimeError(f"HTTP {r.status_code}: {r.text}")
    return r.json()


def models():
    """GET /llm/models."""
    r = httpx.get(f"{BASE}/llm/models", timeout=30)
    r.raise_for_status()
    return r.json()

# %% [markdown]
# ## 1. Which models are available?

# %%
info = models()
print(f"default: {info['default']}   total: {info['total']}")
pd.DataFrame(info["models"])

# %%
# currently resident in memory, and when they expire
pd.DataFrame(info["loaded"])

# %% [markdown]
# ## 2. A single query, end to end
#
# `plan` is the raw model output; `tree` is the query-builder JSON it converts to. When something looks wrong, `plan` tells you whether the model or the conversion is at fault.

# %%
result = parse("adults with cancer or diabetes")
print(json.dumps(result["plan"], indent=2))
print("timings:", result["duration_ms"])

# %%
result["tree"]["demographics"]

# %% [markdown]
# ### Structure only
#
# `fill_concepts=False` skips the database entirely — every `rule.concept` stays `null`. Use it when judging structure rather than concept quality; it is much faster.

# %%
blank = parse("adults with cancer or diabetes", fill_concepts=False)
print(json.dumps(blank["tree"], indent=2))

# %% [markdown]
# ## 3. Readable tree printer

# %%
def show(tree, indent=0):
    """Print the rule tree, one node per line."""
    for node in tree.get("rules", []):
        pad = "  " * indent
        if "combinator" in node:
            print(f"{pad}-- {node['combinator'].upper()} --")
        elif "rules" in node:
            print(f"{pad}GROUP")
            show(node, indent + 1)
        else:
            concept = node["rule"]["concept"]
            if concept is None:
                target = "(blank)"
            elif concept["concept_id"] is None:
                target = f"UNMATCHED {concept['name']!r}"
            else:
                n_alt = len(concept.get("alternatives", []))
                target = f"[{concept['concept_id']}] {concept['name']}  (+{n_alt} alts)"
            extras = []
            if node.get("exclude"):
                extras.append("EXCLUDED")
            for key in ("ageConstraint", "valueAsNumber", "timeConstraint"):
                if key in node:
                    value = node[key]
                    if key == "timeConstraint":
                        value = [v[:10] if v else None for v in value]
                    extras.append(f"{key}={value}")
            suffix = f"   {' '.join(extras)}" if extras else ""
            print(f"{pad}{node['searchTerm']!r} -> {target}{suffix}")


def summarise(result):
    demo = result["tree"]["demographics"]
    death = demo["death"]["label"] if demo["death"] else "-"
    sex = [c["name"] for c in demo["sex"]] or "-"
    race = [c["name"] for c in demo["race"]] or "-"
    print(f"age={demo['age']}  sex={sex}  race={race}  death={death}")
    show(result["tree"])
    for w in result["warnings"]:
        print(f"  ! {w}")

# %%
summarise(parse("women who were under 60 when they suffered a hip fracture"))

# %% [markdown]
# ## 4. Current age vs age at the event
#
# The two readings give different cohorts. A 70-year-old who broke a hip at 55 matches the first query but not the second. Check the age lands in the right place — `demographics.age` for the person, `ageConstraint` on the rule for the event.

# %%
for q in [
    "women who were under 60 when they suffered a hip fracture",
    "women aged 18-45 with endometriosis",
    "patients diagnosed with diabetes before the age of 40",
    "people aged 65+ with hypertension",
]:
    print(f"\n=== {q}")
    summarise(parse(q, fill_concepts=False))

# %% [markdown]
# ## 5. Run the whole set
#
# Structure only, so no database work. Expect roughly 3-6 s per query — budget a few minutes.

# %%
def run_all(queries, fill_concepts=False, model=None):
    rows = []
    for i, (query, note) in enumerate(queries, 1):
        try:
            t0 = time.monotonic()
            result = parse(query, fill_concepts=fill_concepts, model=model)
            secs = time.monotonic() - t0
            demo = result["tree"]["demographics"]
            plan = result["plan"]
            rows.append({
                "query": query,
                "note": note,
                "age": demo["age"],
                "sex": [c["name"] for c in demo["sex"]],
                "race": [c["name"] for c in demo["race"]],
                "death": demo["death"]["label"] if demo["death"] else None,
                "op": plan.get("op"),
                "terms": [r.get("term") or r.get("terms") for r in plan.get("rules", [])],
                "n_warnings": len(result["warnings"]),
                "secs": round(secs, 1),
                "plan": plan,
                "tree": result["tree"],
                "warnings": result["warnings"],
            })
        except Exception as e:
            rows.append({"query": query, "note": note, "error": str(e)})
        print(f"{i}/{len(queries)}", end="\r")
    return pd.DataFrame(rows)


results = run_all(SIMPLE_QUERIES)
results[["query", "age", "sex", "death", "op", "terms", "secs"]]

# %%
advanced = run_all(ADVANCED_QUERIES)
advanced[["query", "age", "sex", "race", "op", "terms", "n_warnings", "secs"]]

# %% [markdown]
# ## 6. Where does it disagree with you?
#
# Some slices for spotting bad parses.

# %%
everything = pd.concat([results, advanced], ignore_index=True)

# any term that still looks like a time window, a number or a demographic
leaked = everything[everything["terms"].astype(str).str.contains(
    r"year|month|week|age|adult|child|male|female|died|death", case=False, na=False
)]
leaked[["query", "terms"]]

# %%
# queries where the model reached for followed_by
everything[everything["op"] == "followed_by"][["query", "terms"]]

# %%
# every warning raised, most common first
counter = Counter(w for ws in everything["warnings"].dropna() for w in ws)
for warning, n in counter.most_common():
    print(f"{n:3d}  {warning}")

# %%
# inspect any single row in full
row = everything.iloc[0]
print(row["query"])
print(json.dumps(row["plan"], indent=2))

# %% [markdown]
# ## 7. Compare models
#
# `model` is a per-request override, so no restart is needed. Pull the other model first (`ollama pull qwen3:14b`).

# %%
# available = [m["name"] for m in models()["models"]]
# comparison = {name: run_all(SIMPLE_QUERIES[:5], model=name) for name in available}
# comparison["qwen3:8b"][["query", "age", "terms", "secs"]]

# %% [markdown]
# ## 8. Concept resolution
#
# With `fill_concepts=True` each blank concept is filled by the existing resolver — the same `resolver.search()` call `/extract` makes. The best match goes in `rule.concept`, the rest into `concept.alternatives`.
#
# Concept *quality* is the existing resolver's behaviour, not the LLM's. Compare against `/extract` below before blaming the model.

# %%
resolved = parse("adults with cancer or diabetes")
summarise(resolved)

# %%
# the same query through the existing pipeline, for comparison
r = httpx.post(f"{BASE}/extract", json={"query": "adults with cancer or diabetes"}, timeout=120)
extract = r.json()
pd.DataFrame([
    {"text": e["text"],
     "concept_id": e["attributes"]["concept_id"],
     "concept_name": e["attributes"]["concept_name"],
     "domain": e["attributes"]["domain_id"]}
    for e in extract["entities"]
]).head(15)
